# %%
import pandas as pd
import numpy as np

def linReg(x_train, y_train, x_test):
    ones = np.ones([x_train.shape[0], 1])
    x_train = np.concatenate((ones, x_train), axis=1)
    ones = np.ones([x_test.shape[0], 1])
    x_test = np.concatenate((ones, x_test), axis=1)
    temp_1 = np.dot(x_train.T, x_train)
    temp_1 = temp_1.astype(np.float64)
    temp_1 = np.linalg.pinv(temp_1)
    temp_2 = np.dot(x_train.T, y_train)
    theta = np.dot(temp_1, temp_2)
    preds = np.dot(x_test, theta)
    return preds

# %%
df = pd.read_csv("Ground_Water_Data\\ground_water_quality_in_andhra_pradesh-2014.csv",
                encoding = "unicode_escape")
df.head(68)
# Out:
#     STATION CODE                                          LOCATIONS  \
# 0           1513  B W. - KRISHNA MURTHY, D.NO. 48-16-43 AUTONAGA...
# 1           1514  B/W. - VIJAY KUMAR AUTONAGAR VIJAYAWADA, KRISH...
# 2           1515  B/W. - NAGARAM(V), PALVONCHA, KHAMMAM DIST., A.P.
# 3           1516                   B W OF NAVLOK GARDENS NELLORE AP
# 4           1517         B/W. - TUNGBHADRA RIVER NEAR KURNOOL, A.P.
# 5           1518                B/W. - NANDYAL, KURNOOL DIST., A.P.
# 6           1519                 B/W. - NAGIRI, CHITTOOR DIST., A.P
# 7           1520  B/W. - SWARNAMUKHI RIVER, SRIKALAHASTI, CHITTO...
# 8           1521  O/W. - NEAR RAMA TEMPLE , WARD NO.2 , MINDI , ...
# 9           1522                O/W. PEDDANUYYI - VIZIANAGARAM, A.P
# 10          1523  B/W. - NEAR M/S ANDHRA SUGARS LTD. , KOVVUR , ...
# 11          1524  O/W. -NEAR PARTAP NAGAR BRIIDGE -KAKINADA , E....
# 12          1795  B/W. - PANCHAYAT OFFICE , , BOLLARAM (V) MEDAK...
# ...

# %%
df_na = df[df.isna().any(axis=1)]
df_na.head()
# Out:
#     STATION CODE                                          LOCATIONS  \
# 0           1513  B W. - KRISHNA MURTHY, D.NO. 48-16-43 AUTONAGA...
# 1           1514  B/W. - VIJAY KUMAR AUTONAGAR VIJAYAWADA, KRISH...
# 2           1515  B/W. - NAGARAM(V), PALVONCHA, KHAMMAM DIST., A.P.
# 3           1516                   B W OF NAVLOK GARDENS NELLORE AP
# 15          3087  BORE WELL NEAR VILLAGE SECRETARIAT, PATHAPADU ...
#
#              STATE  TEMPERATURE ºC : Min  TEMPERATURE ºC : Max  \
# 0   ANDHRA PRADESH                    23                  23.0
# 1   ANDHRA PRADESH                    23                  23.0
# 2   ANDHRA PRADESH                    19                  19.0
# 3   ANDHRA PRADESH                    29                  29.0
# 15  ANDHRA PRADESH                    23                  23.0
#
#     TEMPERATURE ºC : Mean  pH : Min : 6.5-8.5  pH : Max : 6.5-8.5  \
# 0                    23.0                 7.0                 7.0
# ...

# %%
df_train = df.dropna(axis='rows')
df_train.head()
# Out:
#    STATION CODE                                          LOCATIONS  \
# 4          1517         B/W. - TUNGBHADRA RIVER NEAR KURNOOL, A.P.
# 5          1518                B/W. - NANDYAL, KURNOOL DIST., A.P.
# 6          1519                 B/W. - NAGIRI, CHITTOOR DIST., A.P
# 7          1520  B/W. - SWARNAMUKHI RIVER, SRIKALAHASTI, CHITTO...
# 8          1521  O/W. - NEAR RAMA TEMPLE , WARD NO.2 , MINDI , ...
#
#             STATE  TEMPERATURE ºC : Min  TEMPERATURE ºC : Max  \
# 4  ANDHRA PRADESH                    27                  30.6
# 5  ANDHRA PRADESH                    27                  35.0
# 6  ANDHRA PRADESH                    27                  37.0
# 7  ANDHRA PRADESH                    27                  39.5
# 8  ANDHRA PRADESH                    25                  25.0
#
#    TEMPERATURE ºC : Mean  pH : Min : 6.5-8.5  pH : Max : 6.5-8.5  \
# 4                   28.5                 7.2                 8.1
# ...

# %%
dtemp = df[df_na.columns[df_na.isnull().any()]]
dtemp.head(29)
# Out:
#     B.O.D. (mg/l) : Min : < 3 mg/l  B.O.D. (mg/l) : Max : < 3 mg/l  \
# 0                              NaN                             NaN
# 1                              NaN                             NaN
# 2                              0.6                             0.6
# 3                              NaN                             NaN
# 4                              0.8                             1.0
# 5                              1.0                             1.6
# 6                              1.1                             1.8
# 7                              1.1                             1.5
# 8                              1.0                             1.0
# 9                              1.0                             1.2
# 10                             1.0                             1.0
# 11                             1.2                             1.2
# 12                             6.8                             6.8
# ...

# %%
pd.isnull(pd.DataFrame(dtemp.iloc[:,1])).any(1).to_numpy().nonzero()[0]
# Out:
# array([ 0,  1,  3, 15, 16, 28], dtype=int64)

# %%
pd.Index.isnull(df_na)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-38-da8c5e411971> in <module>
# ----> 1 pd.Index.isnull(df_na)
#
# ~\Anaconda3\lib\site-packages\pandas\core\indexes\base.py in isna(self)
#    1869         array([False,  True,  True,  True], dtype=bool)
#    1870         """
# -> 1871         return self._isnan
#    1872     isnull = isna
#    1873
#
# ~\Anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5065             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5066                 return self[name]
# -> 5067             return object.__getattribute__(self, name)
#    5068
#    5069     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute '_isnan'
